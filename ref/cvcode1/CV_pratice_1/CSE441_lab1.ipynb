# %%
# for upload from local drive
from google.colab import files
src = list(files.upload().values())[0]
# Out:
#      <input type="file" id="files-23a25149-335a-4059-8bba-2ef6f9c6577c" name="files[]" multiple disabled />
#      <output id="result-23a25149-335a-4059-8bba-2ef6f9c6577c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving derivative.py to derivative.py
# Saving gaussian_filter.py to gaussian_filter.py
# Saving laplacian_filter.py to laplacian_filter.py

# %%
# !ls -al
# Out:
# total 820
# drwxr-xr-x 1 root root   4096 Oct 11 05:08 .
# drwxr-xr-x 1 root root   4096 Oct 11 04:46 ..
# -rw-r--r-- 1 root root  19545 Oct 11 05:01 cameraman.jpg
# drwxr-xr-x 4 root root   4096 Oct  9 16:23 .config
# -rw-r--r-- 1 root root    584 Oct 11 05:08 derivative.py
# -rw-r--r-- 1 root root    590 Oct 11 05:08 gaussian_filter.py
# -rw-r--r-- 1 root root    578 Oct 11 05:08 laplacian_filter.py
# -rw-r--r-- 1 root root 786486 Oct 11 05:01 lena.bmp

# %%
# !cat *.py

# %%
# derivative.py
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Read image
filename = 'cameraman.jpg'
img = plt.imread(filename)


# Make derivative filter
filter_x = np.array([[-1, 0, 1]])
filter_y = np.array([-1,
                     0,
                     1])


# Apply filter to image
dst = cv2.filter2D(img, -1, filter_x)


# Plot images
plt.subplot(121), plt.imshow(img, cmap='gray'), plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(dst, cmap='gray'), plt.title('derivative')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
# gaussian_filter.py
import cv2
import matplotlib.pyplot as plt
import numpy as np

# Read image
filename = 'cameraman.jpg'
img = plt.imread(filename)


# Get gaussian filter
filter = cv2.getGaussianKernel(ksize=5, sigma=1)


# Make 2D gaussian filter ( Option )
filter = filter * filter.T


# Apply filter to image
dst = cv2.filter2D(img, -1, filter)


# Plot images
plt.subplot(121), plt.imshow(img, cmap='gray'), plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(dst, cmap='gray'), plt.title('Gaussian_blur')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
# laplacian_filter.py
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Read image
filename = 'cameraman.jpg'
img = plt.imread(filename)


# Make laplacian filter
filter = np.array([[-1, -1, -1],
                   [-1,  8, -1],
                   [-1, -1, -1]])


# Apply filter to image
dst = cv2.filter2D(img, -1, filter)


# Plot images
plt.subplot(121), plt.imshow(img, cmap='gray'), plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(dst, cmap='gray'), plt.title('Laplacian_filter')
plt.xticks([]), plt.yticks([])
plt.show()
